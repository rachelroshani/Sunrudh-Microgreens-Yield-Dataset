# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy.stats import skew, kurtosis

# %%
df = pd.read_excel("C:/Users/rache/Downloads/Sunrudh Agri Yield.xlsx")

# %%
df
# Out:
#        Unnamed: 0 Category                   Seed_Type Batch_ID Sowing_Date  \
# 0    Leafy Greens               NaN                NaN      NaN         NaT
# 1               1      Leafy Greens           Broccoli  BRO-001  2025-03-05
# 2               2               NaN               Kale  KAL-002  2025-02-25
# 3               3               NaN            Spinach  SPI-003  2025-04-05
# 4               4               NaN            Lettuce  LET-004  2025-02-05
# ..            ...               ...                ...      ...         ...
# 455           446               NaN    Borettane Onion  ALL-041  2025-07-11
# 456           447               NaN    Bavarian Garlic  ALL-042  2025-07-12
# 457           448               NaN       Bronze Onion  ALL-043  2025-07-13
# 458           449               NaN     Piccolo Garlic  ALL-044  2025-07-14
# 459           450               NaN  Red Torpedo Onion  ALL-045  2025-07-15
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 460 entries, 0 to 459
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            460 non-null    object
#  1   Category              10 non-null     object
#  2   Seed_Type             450 non-null    object
#  3   Batch_ID              450 non-null    object
#  4   Sowing_Date           450 non-null    datetime64[ns]
#  5   Harvest_Date          450 non-null    object
#  6   Growth_Duration_Days  450 non-null    float64
#  7   Sand_Type             450 non-null    object
#  8   Vermicompost_kg       450 non-null    float64
#  9   Cocopeat_kg           450 non-null    float64
#  10  Water_Litres          450 non-null    float64
#  11  Sunlight_Hours        450 non-null    float64
#  12  Temperature_C         450 non-null    float64
#  13  Humidity_%            450 non-null    float64
# ...

# %%
df.isna()
# Out:
#      Unnamed: 0  Category           Seed_Type  Batch_ID  Sowing_Date  \
# 0         False               True       True      True         True
# 1         False              False      False     False        False
# 2         False               True      False     False        False
# 3         False               True      False     False        False
# 4         False               True      False     False        False
# ..          ...                ...        ...       ...          ...
# 455       False               True      False     False        False
# 456       False               True      False     False        False
# 457       False               True      False     False        False
# 458       False               True      False     False        False
# 459       False               True      False     False        False
#
#      Harvest_Date  Growth_Duration_Days  Sand_Type  Vermicompost_kg  \
# 0            True                  True       True             True
# ...

# %%
print(df.shape)
# Out:
# (460, 16)

# %%
desc_stats = df.describe(include=[np.number])
print(desc_stats)
# Out:
#        Growth_Duration_Days  Vermicompost_kg  Cocopeat_kg  Water_Litres  \
# count            450.000000       450.000000   450.000000    450.000000
# mean              10.771111         1.025511     0.757956      9.939178
# std                1.389929         0.164394     0.081226      1.105263
# min                7.000000         0.590000     0.310000      5.120000
# 25%               10.000000         0.900000     0.730000      9.500000
# 50%               10.000000         0.980000     0.760000      9.800000
# 75%               11.000000         1.127500     0.790000     10.200000
# max               16.000000         1.600000     0.950000     14.740000
#
#        Sunlight_Hours  Temperature_C  Humidity_%  Harvest_Yield_grams  \
# count      450.000000     450.000000  450.000000           450.000000
# mean         6.277111      23.240222   70.145333           299.808422
# std          0.375812       1.031856    3.485910            31.835395
# ...

# %%
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
print("Growth days out of range:", df[(df['Growth_Duration_Days'] < 5) | (df['Growth_Duration_Days'] > 25)].shape[0])
print("Temperature out of range:", df[(df['Temperature_C'] < 15) | (df['Temperature_C'] > 35)].shape[0])
print("Invalid yields:", df[df['Harvest_Yield_grams'] <= 0].shape[0])
# Out:
# Growth days out of range: 0
# Temperature out of range: 0
# Invalid yields: 0

# %%
from scipy.stats import skew, kurtosis

numeric_cols = df.select_dtypes(include="number").columns

for col in numeric_cols:
    print(f"\n{col}")
    print("Skewness:", skew(df[col].dropna()))
    print("Kurtosis:", kurtosis(df[col].dropna()))
# Out:
# Growth_Duration_Days
# Skewness: 1.559411563946863
# Kurtosis: 2.7178330673399245
#
# Vermicompost_kg
# Skewness: 0.9018058119391544
# Kurtosis: 1.0163257930766072
#
# Cocopeat_kg
# Skewness: -1.9231955715001343
# Kurtosis: 8.017114777216465
#
# Water_Litres
# Skewness: 0.17663129507936023
# Kurtosis: 6.364795379561556
#
# Sunlight_Hours
# Skewness: -1.1892787874385422
# Kurtosis: 8.706789046293343
#
# Temperature_C
# Skewness: -1.6599590628655059
# Kurtosis: 4.19154821352843
#
# Humidity_%
# Skewness: -3.5472381207937
# Kurtosis: 15.101663104049436
#
# Harvest_Yield_grams
# Skewness: 1.0584389145197706
# Kurtosis: 1.4848171675032855
#
# Yield_per_sqm
# Skewness: 1.4025042438913544
# Kurtosis: 3.09360432300476

# %%
numeric_cols = ["Growth_Duration_Days", "Harvest_Yield_grams", "Temperature_C", "Humidity_%"]

for col in numeric_cols:
    sns.histplot(df[col], kde=True, bins=20)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Count")
    plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()
